# %% [markdown]
# <a href="https://colab.research.google.com/github/jaalvaradoh/s6/blob/main/s6_parte2_Maldicion_de_la_dimensionalidad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://miro.medium.com/v2/resize:fit:1400/1*zomnCz8-VMgrSV8eLCx2tw.gif" width="200" alt="molecula"  />
#
# $$\Large \textit{Cuaderno de Código #5 | Sesión Nº 6}$$
#
# ---
# $$\large\textbf{La Maldición de la Dimensionalidad}$$
#
# ---
# $$\textit{Parte 2}$$
#
# <br>
# <br>
#
# __Dr. Jesus Alvarado-Huayhuaz__

# %% [markdown]
# # 1. Requerimientos

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 2. Generación de datos

# %%
x = np.random.randint(10, size=10)
y = np.random.randint(10, size=10)
z = np.random.randint(10, size=10)
x,y,z
# Out:
# (array([9, 9, 5, 8, 0, 0, 6, 2, 6, 3]),
#  array([2, 4, 2, 4, 2, 1, 1, 3, 7, 3]),
#  array([8, 6, 8, 3, 7, 4, 2, 3, 0, 3]))

# %% [markdown]
# # 3. Visualización

# %%
fig = plt.figure(figsize=(18,6))

#espacio unidimensinonal
ax = fig.add_subplot(1,3,1)
ax.plot(x, [0]*10, linewidth=0,marker='*',
        color="purple",markersize=20)

#espacio bidimensional
ax = fig.add_subplot(1,3,2)
ax.scatter(x, y, marker='*',
        c="purple",s=200)

#espacio tridimensional
ax = fig.add_subplot(1,3,3, projection="3d")
ax.scatter(x, y, z, marker='*',
        c="purple",s=200)

plt.show()

# %% [markdown]
# En la figura de la izquierda, 7 de 10 espacios en la horizontal; en el centro, 10 en el espacio bidimensional y finalmente, 10 puntos (estrellas) en el espacio tridimensional.

# %% [markdown]
# # 4. Conclusiones

# %%
fig = plt.figure(figsize=(18,6))

#espacio unidimensinonal
ax = fig.add_subplot(1,3,1)
ax.set_title("10E1 = 10", fontsize=35)

ax.plot(range(0,10), [0]*10,
        marker="o",linewidth=0,
        color="skyblue",markersize=20)

ax.plot(x, [0]*10, linewidth=0,marker='*',
        color="purple",markersize=20)

#espacio bidimensional
ax = fig.add_subplot(1,3,2)

ax.set_title("10E2 = 100", fontsize=35)

for i in range(10):
  ax.scatter(range(0,10), [i]*10, marker='*',
        c="skyblue",s=200)

ax.scatter(x,y, marker="*",c="purple",s=200)

#espacio tridimensional
ax = fig.add_subplot(1,3,3, projection="3d")

ax.set_title("10E3 = 1000",fontsize=35)

for i in range(10):
  for j in range(10):
    ax.scatter(range(0,10), [i]*10,j,
               marker='*',c="skyblue",
               s=200,alpha=0.25)

ax.scatter(x,y,z, marker="*",c="purple",s=200)

plt.show()

# %% [markdown]
# Los datos ocupados son:

# %% [markdown]
# - Izquierda: 70%
#
# - Centro: 10%
#
# - Derecha: 1%
